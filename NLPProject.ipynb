# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk as nltk
from nltk.tokenize import word_tokenize
import string
nltk.download('punkt')
import re
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
fb = pd.read_excel("/content/finalDataset.xlsx")
print(fb.head(5))
# Out:
#    teaching                                         teaching.1
# 0         0  teacher are punctual but they should also give...
# 1         1                                              Good
# 2         1  Excellent lectures are delivered by teachers a...
# 3         1                                               Good
# 4         1  teachers give us all the information required ...

# %%
def remove_punct(text):
  text_nopunct = "".join([char for char in text if char not in string.punctuation])
  return text_nopunct

fb['body_text_nopunc'] = fb['teaching.1'].apply(lambda x: remove_punct(x.lower()))
fb.head()
# Out:
#    teaching                                         teaching.1  \
# 0         0  teacher are punctual but they should also give...
# 1         1                                              Good
# 2         1  Excellent lectures are delivered by teachers a...
# 3         1                                               Good
# 4         1  teachers give us all the information required ...
#
#                                     body_text_nopunc
# 0  teacher are punctual but they should also give...
# 1                                              good
# 2  excellent lectures are delivered by teachers a...
# 3                                               good
# 4  teachers give us all the information required ...

# %%
def tokenize(text):
  tokens = word_tokenize(text)
  return tokens

fb['body_text_tokenized'] = fb['body_text_nopunc'].apply(lambda x: tokenize(x))
fb.head()
# Out:
#    teaching                                         teaching.1  \
# 0         0  teacher are punctual but they should also give...
# 1         1                                              Good
# 2         1  Excellent lectures are delivered by teachers a...
# 3         1                                               Good
# 4         1  teachers give us all the information required ...
#
#                                     body_text_nopunc  \
# 0  teacher are punctual but they should also give...
# 1                                              good
# 2  excellent lectures are delivered by teachers a...
# 3                                               good
# 4  teachers give us all the information required ...
#
#                                  body_text_tokenized
# 0  [teacher, are, punctual, but, they, should, al...
# 1                                             [good]
# 2  [excellent, lectures, are, delivered, by, teac...
# 3                                             [good]
# 4  [teachers, give, us, all, the, information, re...

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
words_to_keep = ["not", "but", "no", "don't", "can't", "didn't", "doesn't",
                 "hasn't", "won't", "shouldn't", "couldn't", "isn't","aren't"
                 "wasn't", "wouldn't", "never", "none", "neither", "nor"]
custom_stop_words = set(word for word in stop_words if word not in words_to_keep)
def remove_stopwords(tokenized_list):
  text = [word for word in tokenized_list if word not in custom_stop_words]
  return text

fb['body_text_nostop'] = fb['body_text_tokenized'].apply(lambda x: remove_stopwords(x))
fb.head()
# Out:
#    teaching                                         teaching.1  \
# 0         0  teacher are punctual but they should also give...
# 1         1                                              Good
# 2         1  Excellent lectures are delivered by teachers a...
# 3         1                                               Good
# 4         1  teachers give us all the information required ...
#
#                                     body_text_nopunc  \
# 0  teacher are punctual but they should also give...
# 1                                              good
# 2  excellent lectures are delivered by teachers a...
# 3                                               good
# 4  teachers give us all the information required ...
#
#                                  body_text_tokenized  \
# 0  [teacher, are, punctual, but, they, should, al...
# 1                                             [good]
# 2  [excellent, lectures, are, delivered, by, teac...
# 3                                             [good]
# 4  [teachers, give, us, all, the, information, re...
#
#                                     body_text_nostop
# 0  [teacher, punctual, but, also, give, us, pract...
# 1                                             [good]
# 2  [excellent, lectures, delivered, teachers, tea...
# 3                                             [good]
# 4  [teachers, give, us, information, required, im...

# %%
def tokenize_re(text):
  tokens_re = re.split('\W+',text)
  return tokens_re

fb['body_text_tokenized_re'] = fb['body_text_nopunc'].apply(lambda x: tokenize_re(x))
fb.head()
# Out:
#    teaching                                         teaching.1  \
# 0         0  teacher are punctual but they should also give...
# 1         1                                              Good
# 2         1  Excellent lectures are delivered by teachers a...
# 3         1                                               Good
# 4         1  teachers give us all the information required ...
#
#                                     body_text_nopunc  \
# 0  teacher are punctual but they should also give...
# 1                                              good
# 2  excellent lectures are delivered by teachers a...
# 3                                               good
# 4  teachers give us all the information required ...
#
#                                  body_text_tokenized  \
# 0  [teacher, are, punctual, but, they, should, al...
# 1                                             [good]
# 2  [excellent, lectures, are, delivered, by, teac...
# 3                                             [good]
# 4  [teachers, give, us, all, the, information, re...
#
#                                     body_text_nostop  \
# 0  [teacher, punctual, but, also, give, us, pract...
# 1                                             [good]
# 2  [excellent, lectures, delivered, teachers, tea...
# 3                                             [good]
# 4  [teachers, give, us, information, required, im...
#
#                               body_text_tokenized_re
# 0  [teacher, are, punctual, but, they, should, al...
# 1                                           [good, ]
# 2  [excellent, lectures, are, delivered, by, teac...
# 3                                             [good]
# 4  [teachers, give, us, all, the, information, re...

# %%
import nltk
ps=nltk.PorterStemmer()

# %%
def stemmrizing(text):
  for word in text:
    ps.stem(word)
  return text
fb['body_text_stemmer'] = fb['body_text_nostop'].apply(lambda myList: [ps.stem(word) for word in myList])
fb.head()
# Out:
#    teaching                                         teaching.1  \
# 0         0  teacher are punctual but they should also give...
# 1         1                                              Good
# 2         1  Excellent lectures are delivered by teachers a...
# 3         1                                               Good
# 4         1  teachers give us all the information required ...
#
#                                     body_text_nopunc  \
# 0  teacher are punctual but they should also give...
# 1                                              good
# 2  excellent lectures are delivered by teachers a...
# 3                                               good
# 4  teachers give us all the information required ...
#
#                                  body_text_tokenized  \
# 0  [teacher, are, punctual, but, they, should, al...
# 1                                             [good]
# 2  [excellent, lectures, are, delivered, by, teac...
# 3                                             [good]
# 4  [teachers, give, us, all, the, information, re...
#
#                                     body_text_nostop  \
# 0  [teacher, punctual, but, also, give, us, pract...
# 1                                             [good]
# 2  [excellent, lectures, delivered, teachers, tea...
# 3                                             [good]
# 4  [teachers, give, us, information, required, im...
#
#                               body_text_tokenized_re  \
# 0  [teacher, are, punctual, but, they, should, al...
# 1                                           [good, ]
# 2  [excellent, lectures, are, delivered, by, teac...
# 3                                             [good]
# 4  [teachers, give, us, all, the, information, re...
#
#                                    body_text_stemmer
# 0  [teacher, punctual, but, also, give, us, pract...
# 1                                             [good]
# 2  [excel, lectur, deliv, teacher, teacher, punct...
# 3                                             [good]
# 4  [teacher, give, us, inform, requir, improv, pe...

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
wn = WordNetLemmatizer()

def lemmatize(text):
    lemmatized_text = [wn.lemmatize(word) for word  in text]
    return lemmatized_text

fb["body_text_lemmatizer"]=fb['body_text_nostop'].apply(lambda x: lemmatize(x))
fb.head()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#    teaching                                         teaching.1  \
# 0         0  teacher are punctual but they should also give...
# 1         1                                              Good
# 2         1  Excellent lectures are delivered by teachers a...
# 3         1                                               Good
# 4         1  teachers give us all the information required ...
#
#                                     body_text_nopunc  \
# 0  teacher are punctual but they should also give...
# 1                                              good
# 2  excellent lectures are delivered by teachers a...
# 3                                               good
# 4  teachers give us all the information required ...
#
#                                  body_text_tokenized  \
# 0  [teacher, are, punctual, but, they, should, al...
# 1                                             [good]
# 2  [excellent, lectures, are, delivered, by, teac...
# 3                                             [good]
# 4  [teachers, give, us, all, the, information, re...
#
#                                     body_text_nostop  \
# 0  [teacher, punctual, but, also, give, us, pract...
# 1                                             [good]
# 2  [excellent, lectures, delivered, teachers, tea...
# 3                                             [good]
# 4  [teachers, give, us, information, required, im...
#
#                               body_text_tokenized_re  \
# 0  [teacher, are, punctual, but, they, should, al...
# 1                                           [good, ]
# 2  [excellent, lectures, are, delivered, by, teac...
# 3                                             [good]
# 4  [teachers, give, us, all, the, information, re...
#
#                                    body_text_stemmer  \
# 0  [teacher, punctual, but, also, give, us, pract...
# 1                                             [good]
# 2  [excel, lectur, deliv, teacher, teacher, punct...
# 3                                             [good]
# 4  [teacher, give, us, inform, requir, improv, pe...
#
#                                 body_text_lemmatizer
# 0  [teacher, punctual, but, also, give, u, practi...
# 1                                             [good]
# 2  [excellent, lecture, delivered, teacher, teach...
# 3                                             [good]
# 4  [teacher, give, u, information, required, impr...

# %%
from collections import Counter
def most_frequent_words(target_value, top_n):
    # Filter the DataFrame based on the 'teaching' column
    filtered_fb = fb[fb['teaching'] == target_value]

    # Combine the lemmatized text from the filtered rows into a single list
    lemmatized_text = [word for sublist in filtered_fb['body_text_lemmatizer'] for word in sublist]

    # Calculate word frequencies
    word_counts = Counter(lemmatized_text)

    # Get the top N most frequent words
    top_words = word_counts.most_common(top_n)

    return top_words

top_words_teaching_1 = most_frequent_words( 1, 30)
top_words_teaching_0 = most_frequent_words( 0, 30)
top_words_teaching_minus_1 = most_frequent_words( -1, 30)

print("\n most frequent words in positive feedbacks:")
print(top_words_teaching_1)

print("\n most frequent words in neutral feedbacks:")
print(top_words_teaching_0)

print("\n most frequent words in negative feedbacks:")
print(top_words_teaching_minus_1)
# Out:
#  most frequent words in positive feedbacks:
# [('good', 117), ('lecture', 20), ('university', 19), ('teacher', 17), ('delivery', 15), ('teaching', 13), ('interaction', 12), ('punctuality', 12), ('punctual', 9), ('student', 9), ('excellent', 7), ('but', 7), ('term', 6), ('not', 6), ('activity', 5), ('faculty', 5), ('time', 5), ('way', 4), ('everything', 4), ('quite', 4), ('depends', 4), ('satisfied', 4), ('also', 4), ('perfect', 3), ('interact', 3), ('well', 3), ('enough', 3), ('knowledge', 3), ('always', 3), ('every', 3)]
#
#  most frequent words in neutral feedbacks:
# [('but', 24), ('good', 20), ('not', 14), ('teaching', 13), ('student', 13), ('teacher', 11), ('interaction', 10), ('delivery', 7), ('punctuality', 7), ('lecture', 7), ('average', 7), ('faculty', 5), ('also', 4), ('university', 4), ('subject', 4), ('well', 4), ('lecturer', 4), ('people', 4), ('much', 3), ('fine', 3), ('really', 3), ('management', 3), ('need', 3), ('punctual', 2), ('u', 2), ('knowledge', 2), ('way', 2), ('still', 2), ('concept', 2), ('every', 2)]
#
#  most frequent words in negative feedbacks:
# [('not', 9), ('good', 7), ('lecture', 5), ('term', 5), ('teacher', 5), ('delivery', 4), ('but', 4), ('dont', 4), ('student', 4), ('indian', 4), ('subject', 3), ('also', 2), ('interact', 2), ('faculty', 2), ('well', 2), ('experienced', 2), ('interaction', 2), ('wd', 2), ('showing', 2), ('partiality', 2), ('north', 2), ('south', 2), ('goodin', 1), ('punctuality', 1), ('intraction', 1), ('bad', 1), ('donot', 1), ('litsn', 1), ('problms', 1), ('mean', 1)]

# %%
# Define positive, neutral, and negative keywords based on word frequencies
positive_keywords = ['good', 'excellent', 'satisfied', 'perfect', 'well', 'interaction', 'punctual']
neutral_keywords = ['but', 'average', 'fine', 'okay', 'not', 'average']
negative_keywords = ['not', 'bad', 'unsatisfied', 'poor', 'negative', 'dont', 'showing', 'partiality']



# Function to count positive, neutral, and negative words in a text
def count_sentiment_words(text):
    positive_count = sum(text.count(keyword) for keyword in positive_keywords)
    neutral_count = sum(text.count(keyword) for keyword in neutral_keywords)
    negative_count = sum(text.count(keyword) for keyword in negative_keywords)
    return positive_count, neutral_count, negative_count

# Apply the count_sentiment_words function to each feedback
fb[['positive_count', 'neutral_count', 'negative_count']] = fb['body_text_lemmatizer'].apply(count_sentiment_words).apply(pd.Series)

# Function to classify sentiment based on keyword counts
def classify_sentiment_with_counts(row):
    if row['positive_count'] > row['neutral_count'] and row['positive_count'] > row['negative_count']:
        return 1  # Positive sentiment
    elif row['negative_count'] > row['neutral_count'] and row['negative_count'] > row['positive_count']:
        return -1  # Negative sentiment
    else:
        return 0  # Neutral sentiment

# Apply the sentiment classification function to each row
fb['predicted_sentiment_with_counts'] = fb.apply(classify_sentiment_with_counts, axis=1)

# Calculate accuracy
accuracy = (fb['predicted_sentiment_with_counts'] == fb['teaching']).sum() / len(fb)

print(f"Accuracy: {accuracy * 100:.2f}%")
fb.tail(20)
# Out:
# Accuracy: 81.08%
#      teaching                                         teaching.1  \
# 165         1                                        good enough
# 166         1  In this university there is good interaction w...
# 167         1                                 Very good indeed.
# 168         1  Teaching is excellent,but lecture delivery is ...
# 169         0  interaction of some faculty was good but not a...
# 170         1             good, and also like the teaching style
# 171         1  Interaction between students and teachers is g...
# 172         1                                            not bad
# 173         1                                     Its Quite Good
# 174         1                                   very good indeed
# 175         1                                          not bad..
# 176         0  teaching is good some lecturers are showing pa...
# 177         0  I WAS A STUDENT OF A BOARDING SCHOOL .....(jnv...
# 178         1  All terms are good regarding the university ac...
# 179         1                                               GOOD
# 180         1  intraction is good and leacture delivery also ...
# 181         1  all the given terms are good regarding the uni...
# 182         1  All the terms are good regarding the universit...
# 183        -1  Some of the teacher are un experienced. Also t...
# 184         1                                   IT IS GOING GOOD
#
#                                       body_text_nopunc  \
# 165                                        good enough
# 166  in this university there is good interaction w...
# 167                                  very good indeed
# 168  teaching is excellentbut lecture delivery is n...
# 169  interaction of some faculty was good but not a...
# 170              good and also like the teaching style
# 171  interaction between students and teachers is g...
# 172                                            not bad
# 173                                     its quite good
# 174                                   very good indeed
# 175                                            not bad
# 176  teaching is good some lecturers are showing pa...
# 177  i was a student of a boarding school jnv i stu...
# 178  all terms are good regarding the university ac...
# 179                                               good
# 180  intraction is good and leacture delivery also ...
# 181  all the given terms are good regarding the uni...
# 182  all the terms are good regarding the universit...
# 183  some of the teacher are un experienced also th...
# 184                                   it is going good
#
#                                    body_text_tokenized  \
# 165                                     [good, enough]
# 166  [in, this, university, there, is, good, intera...
# 167                               [very, good, indeed]
# 168  [teaching, is, excellentbut, lecture, delivery...
# 169  [interaction, of, some, faculty, was, good, bu...
# 170      [good, and, also, like, the, teaching, style]
# 171  [interaction, between, students, and, teachers...
# 172                                         [not, bad]
# 173                                 [its, quite, good]
# 174                               [very, good, indeed]
# 175                                         [not, bad]
# 176  [teaching, is, good, some, lecturers, are, sho...
# 177  [i, was, a, student, of, a, boarding, school, ...
# 178  [all, terms, are, good, regarding, the, univer...
# 179                                             [good]
# 180  [intraction, is, good, and, leacture, delivery...
# 181  [all, the, given, terms, are, good, regarding,...
# 182  [all, the, terms, are, good, regarding, the, u...
# 183  [some, of, the, teacher, are, un, experienced,...
# 184                              [it, is, going, good]
#
#                                       body_text_nostop  \
# 165                                     [good, enough]
# 166  [university, good, interaction, students, teac...
# 167                                     [good, indeed]
# 168  [teaching, excellentbut, lecture, delivery, no...
# 169    [interaction, faculty, good, but, not, faculty]
# 170                [good, also, like, teaching, style]
# 171  [interaction, students, teachers, good, lectur...
# 172                                         [not, bad]
# 173                                      [quite, good]
# 174                                     [good, indeed]
# 175                                         [not, bad]
# 176  [teaching, good, lecturers, showing, partialit...
# 177  [student, boarding, school, jnv, studied, 7, y...
# 178   [terms, good, regarding, university, activities]
# 179                                             [good]
# 180  [intraction, good, leacture, delivery, also, g...
# 181        [given, terms, good, regarding, university]
# 182   [terms, good, regarding, university, activities]
# 183  [teacher, un, experienced, also, unfair, baise...
# 184                                      [going, good]
#
#                                 body_text_tokenized_re  \
# 165                                     [good, enough]
# 166  [in, this, university, there, is, good, intera...
# 167                             [very, good, indeed, ]
# 168  [teaching, is, excellentbut, lecture, delivery...
# 169  [interaction, of, some, faculty, was, good, bu...
# 170      [good, and, also, like, the, teaching, style]
# 171  [interaction, between, students, and, teachers...
# 172                                         [not, bad]
# 173                                 [its, quite, good]
# 174                               [very, good, indeed]
# 175                                         [not, bad]
# 176  [teaching, is, good, some, lecturers, are, sho...
# 177  [i, was, a, student, of, a, boarding, school, ...
# 178  [all, terms, are, good, regarding, the, univer...
# 179                                             [good]
# 180  [intraction, is, good, and, leacture, delivery...
# 181  [all, the, given, terms, are, good, regarding,...
# 182  [all, the, terms, are, good, regarding, the, u...
# 183  [some, of, the, teacher, are, un, experienced,...
# 184                              [it, is, going, good]
#
#                                      body_text_stemmer  \
# 165                                     [good, enough]
# 166  [univers, good, interact, student, teacher, un...
# 167                                       [good, inde]
# 168  [teach, excellentbut, lectur, deliveri, not, m...
# 169       [interact, faculti, good, but, not, faculti]
# 170                   [good, also, like, teach, style]
# 171  [interact, student, teacher, good, lectur, del...
# 172                                         [not, bad]
# 173                                       [quit, good]
# 174                                       [good, inde]
# 175                                         [not, bad]
# 176  [teach, good, lectur, show, partial, south, pe...
# 177  [student, board, school, jnv, studi, 7, year, ...
# 178               [term, good, regard, univers, activ]
# 179                                             [good]
# 180  [intract, good, leactur, deliveri, also, good,...
# 181               [given, term, good, regard, univers]
# 182               [term, good, regard, univers, activ]
# 183  [teacher, un, experienc, also, unfair, bais, i...
# 184                                         [go, good]
#
#                                   body_text_lemmatizer  positive_count  \
# 165                                     [good, enough]               1
# 166  [university, good, interaction, student, teach...               3
# 167                                     [good, indeed]               1
# 168  [teaching, excellentbut, lecture, delivery, no...               1
# 169    [interaction, faculty, good, but, not, faculty]               2
# 170                [good, also, like, teaching, style]               1
# 171  [interaction, student, teacher, good, lecture,...               3
# 172                                         [not, bad]               0
# 173                                      [quite, good]               1
# 174                                     [good, indeed]               1
# 175                                         [not, bad]               0
# 176  [teaching, good, lecturer, showing, partiality...               1
# 177  [student, boarding, school, jnv, studied, 7, y...               1
# 178      [term, good, regarding, university, activity]               1
# 179                                             [good]               1
# 180  [intraction, good, leacture, delivery, also, g...               3
# 181         [given, term, good, regarding, university]               1
# 182      [term, good, regarding, university, activity]               1
# 183  [teacher, un, experienced, also, unfair, baise...               0
# 184                                      [going, good]               1
#
#      neutral_count  negative_count  predicted_sentiment_with_counts
# 165              0               0                                1
# 166              0               0                                1
# 167              0               0                                1
# 168              1               1                                0
# 169              2               1                                0
# 170              0               0                                1
# 171              1               0                                1
# 172              1               2                               -1
# 173              0               0                                1
# 174              0               0                                1
# 175              1               2                               -1
# 176              0               2                               -1
# 177              2               0                                0
# 178              0               0                                1
# 179              0               0                                1
# 180              0               0                                1
# 181              0               0                                1
# 182              0               0                                1
# 183              0               0                                0
# 184              0               0                                1
